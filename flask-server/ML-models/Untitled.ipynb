# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot
import seaborn as sns
import pickle

# %%
df = pd.read_csv('pricedataset.csv')

# %%
df.head()
# Out:
#    QUOTE_DATE  ITEM_ID                      ITEM_DESC  VALIDITY  SHOP_CODE  \
# 0      202301   210102  LGE LOAF-WHTE-UNSLED-750-800G         3        801
# 1      202301   210102  LGE LOAF-WHTE-UNSLED-750-800G         3        802
# 2      202301   210102  LGE LOAF-WHTE-UNSLED-750-800G         3        803
# 3      202301   210102  LGE LOAF-WHTE-UNSLED-750-800G         3        807
# 4      202301   210102  LGE LOAF-WHTE-UNSLED-750-800G         3        808
#
#    PRICE INDICATOR_BOX ORIG_INDICATOR_BOX  PRICE_RELATIVE  LOG_PRICE_RELATIVE  \
# 0   1.30           NaN                NaN           1.130               0.123
# 1   2.00           NaN                NaN           1.429               0.357
# 2   1.25           NaN                NaN           1.087               0.083
# 3   1.30           NaN                NaN           1.153               0.142
# 4   1.25           NaN                NaN           1.087               0.083
#
# ...

# %%
df.shape
# Out:
# (139419, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139419 entries, 0 to 139418
# Data columns (total 20 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   QUOTE_DATE          139419 non-null  int64
#  1   ITEM_ID             139419 non-null  int64
#  2   ITEM_DESC           139419 non-null  object
#  3   VALIDITY            139419 non-null  int64
#  4   SHOP_CODE           139419 non-null  int64
#  5   PRICE               139419 non-null  float64
#  6   INDICATOR_BOX       42864 non-null   object
#  7   ORIG_INDICATOR_BOX  41603 non-null   object
#  8   PRICE_RELATIVE      139419 non-null  float64
#  9   LOG_PRICE_RELATIVE  139419 non-null  float64
#  10  STRATUM_WEIGHT      139419 non-null  float64
#  11  STRATUM_TYPE        139419 non-null  int64
#  12  START_DATE          139419 non-null  int64
#  13  END_DATE            139419 non-null  int64
#  14  REGION              139419 non-null  int64
# ...

# %%
df = df.drop("QUOTE_DATE", axis=1)
df
# Out:
#         ITEM_ID                      ITEM_DESC  VALIDITY  SHOP_CODE   PRICE  \
# 0        210102  LGE LOAF-WHTE-UNSLED-750-800G         3        801    1.30
# 1        210102  LGE LOAF-WHTE-UNSLED-750-800G         3        802    2.00
# 2        210102  LGE LOAF-WHTE-UNSLED-750-800G         3        803    1.25
# 3        210102  LGE LOAF-WHTE-UNSLED-750-800G         3        807    1.30
# 4        210102  LGE LOAF-WHTE-UNSLED-750-800G         3        808    1.25
# ...         ...                            ...       ...        ...     ...
# 139414   640406            HOTEL 1 NIGHT PRICE         1       5105    0.00
# 139415   640406            HOTEL 1 NIGHT PRICE         3       5112  150.00
# 139416   640406            HOTEL 1 NIGHT PRICE         3      15451  110.00
# 139417   640406            HOTEL 1 NIGHT PRICE         3      15689  132.00
# 139418   640406            HOTEL 1 NIGHT PRICE         3      18022  135.00
#
# ...

# %%
x = df.drop("ITEM_ID", axis=1)
x = x.drop("VALIDITY", axis=1)
x = x.drop("SHOP_CODE", axis=1)
x = x.drop("INDICATOR_BOX", axis=1)
x = x.drop("ORIG_INDICATOR_BOX", axis=1)
x = x.drop("REGION", axis=1)
x = x.drop("SHOP_TYPE", axis=1)

# %%
x
# Out:
#                             ITEM_DESC   PRICE  PRICE_RELATIVE  \
# 0       LGE LOAF-WHTE-UNSLED-750-800G    1.30           1.130
# 1       LGE LOAF-WHTE-UNSLED-750-800G    2.00           1.429
# 2       LGE LOAF-WHTE-UNSLED-750-800G    1.25           1.087
# 3       LGE LOAF-WHTE-UNSLED-750-800G    1.30           1.153
# 4       LGE LOAF-WHTE-UNSLED-750-800G    1.25           1.087
# ...                               ...     ...             ...
# 139414            HOTEL 1 NIGHT PRICE    0.00           0.000
# 139415            HOTEL 1 NIGHT PRICE  150.00           0.935
# 139416            HOTEL 1 NIGHT PRICE  110.00           1.049
# 139417            HOTEL 1 NIGHT PRICE  132.00           1.320
# 139418            HOTEL 1 NIGHT PRICE  135.00           0.998
#
#         LOG_PRICE_RELATIVE  STRATUM_WEIGHT  STRATUM_TYPE  START_DATE  \
# 0                    0.123           11.92             1      202202
# 1                    0.357           11.92             1      202202
# ...
